# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# - Pandas is Python Library for **Data Analysis**
# - It depends on NumPy
# - Three types of data structures in Pandas
#     - Series (one-dimensional) - represent a Column or Row
#     - DataFrame (two-dimensional) - represent a Table (rows and columns)
#     - Panel (three-dimensional - obsolete)
#     - MutliIndex DataFrame (instead of panel data structure)

# %% [markdown]
# ##### Installing Pandas library
# ```python
# # Using cmd (command prompt)
# pip install pandas
#
# # In Jupyter Notebook
# !pip install pandas
# conda install pandas
# ```

# %% [markdown]
# #### Import Pandas to Use it
# ```python
# import pandas as pd
# ```

# %%
# imports
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series

# %% [markdown]
# - It is one-dimensional data structure
# - It contains two aspects - data and index
# - By default, index is a sequence of numbers like list object's index
# - However, we can specify the custom index
# - Additionally, we can specify the datatype (dtype) of Series

# %%
# creating a series of numbers using Series class
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
s1 = pd.Series([10, 20, 30, 40])
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# np.nan is a missing value; data parameter to specify the data
s2 = pd.Series(data=[100, 200, 300, np.nan, 500])
s2
# Out:
# 0    100.0
# 1    200.0
# 2    300.0
# 3      NaN
# 4    500.0
# dtype: float64

# %% [markdown]
# #### np.nan
# - Represent a missing value from NumPy
# - NaN stands for not a number, but is actually a very small floating-number

# %% [markdown]
# #### In a Series or DataFrame we see an Index on the left-side
# - Index numbers start from 0 (0 to n-1)
# - In Series, index represents individual values
# - In DataFrame, index represents a row
# - However, a column can also be represent by column_index in DataFrame

# %%
# use the index parameter to specify a custom index
s3 = pd.Series(data=['Dosa', 'Upma', 'Idly', 'Puri', 'Vada'],
              index=['Mon', 'Tue', 'Wed', 'Thu', 'Fri'])
s3
# Out:
# Mon    Dosa
# Tue    Upma
# Wed    Idly
# Thu    Puri
# Fri    Vada
# dtype: object

# %%
s2
# Out:
# 0    100.0
# 1    200.0
# 2    300.0
# 3      NaN
# 4    500.0
# dtype: float64

# %%
s2[2]
# Out:
# 300.0

# %%
s3
# Out:
# Mon    Dosa
# Tue    Upma
# Wed    Idly
# Thu    Puri
# Fri    Vada
# dtype: object

# %%
s3['Wed']
# Out:
# 'Idly'

# %%
# A Series from a dictionary
routine = {'Mon':'Python', 'Tue':'NumPy', 'Wed':'pandas', 'Thu':'sk-learn',
          'Fri':'tensorflow'}
# keys become index and values are series values
s4 = pd.Series(routine)
s4
# Out:
# Mon        Python
# Tue         NumPy
# Wed        pandas
# Thu      sk-learn
# Fri    tensorflow
# dtype: object

# %%
# A Series from a set
colors = {'red', 'green', 'blue', 'white', 'black'}
# pd.Series(colors)
pd.Series(list(colors))
# Out:
# 0      red
# 1    black
# 2    green
# 3    white
# 4     blue
# dtype: object

# %%
# A Series from random values generated using NumPy library functions
random = np.random.randint(1, 101, 10)
pd.Series(random)
# Out:
# 0    25
# 1    38
# 2    43
# 3    62
# 4    56
# 5    43
# 6    61
# 7    43
# 8    82
# 9    13
# dtype: int32

# %%
# dtype parameter to specify the data type of a series
pd.Series([1, 2, 3, 4, 5], dtype='int')
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
pd.Series([1, 2, 3, 4, 5], dtype='float')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
s3
# Out:
# Mon    Dosa
# Tue    Upma
# Wed    Idly
# Thu    Puri
# Fri    Vada
# dtype: object

# %%
s2
# Out:
# 0    100.0
# 1    200.0
# 2    300.0
# 3      NaN
# 4    500.0
# dtype: float64

# %%
s5 = pd.Series([True, False, True, True, True, False])
s5
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
s2
# Out:
# 0    100.0
# 1    200.0
# 2    300.0
# 3      NaN
# 4    500.0
# dtype: float64

# %%
s3
# Out:
# Mon    Dosa
# Tue    Upma
# Wed    Idly
# Thu    Puri
# Fri    Vada
# dtype: object

# %%
### Attributes of Series

# %%
s3
# Out:
# Mon    Dosa
# Tue    Upma
# Wed    Idly
# Thu    Puri
# Fri    Vada
# dtype: object

# %%
s3.values
# Out:
# array(['Dosa', 'Upma', 'Idly', 'Puri', 'Vada'], dtype=object)

# %%
s3.index
# Out:
# Index(['Mon', 'Tue', 'Wed', 'Thu', 'Fri'], dtype='object')

# %%
s3.dtype
# Out:
# dtype('O')

# %%
s3.shape
# Out:
# (5,)

# %%
s3.size
# Out:
# 5

# %%
s3.is_unique # no duplicates
# Out:
# True

# %%
s6 = pd.Series([1, 2, 3, 1, 4])
s6.is_unique  # duplicates
# Out:
# False

# %%
# monotonic (increasing or decreasing) series
s7 = pd.Series([5, 7, 25, 40, 99, 103])
s7.is_monotonic_increasing
# Out:
# True

# %%
s7.is_monotonic_decreasing
# Out:
# False

# %%
s8 = pd.Series([5, 7, 85, 40, 99, 103])
s8.is_monotonic_increasing
# Out:
# False

# %%
s8.is_monotonic_decreasing
# Out:
# False

# %%
s9 = pd.Series(random)
s9
# Out:
# 0    25
# 1    38
# 2    43
# 3    62
# 4    56
# 5    43
# 6    61
# 7    43
# 8    82
# 9    13
# dtype: int32

# %% [markdown]
# ### Methods of Series

# %%
s9
# Out:
# 0    25
# 1    38
# 2    43
# 3    62
# 4    56
# 5    43
# 6    61
# 7    43
# 8    82
# 9    13
# dtype: int32

# %%
# head(n) - specify how many starting elements you want
s9.head(3)
# Out:
# 0    25
# 1    38
# 2    43
# dtype: int32

# %%
s9.head(5)
# Out:
# 0    25
# 1    38
# 2    43
# 3    62
# 4    56
# dtype: int32

# %%
s9.head(2)
# Out:
# 0    25
# 1    38
# dtype: int32

# %%
# head(n) - default value of n is 5
s9.head()
# Out:
# 0    25
# 1    38
# 2    43
# 3    62
# 4    56
# dtype: int32

# %%
# tail(n) - shows last values; default value of n is 5
s9.tail(3)
# Out:
# 7    43
# 8    82
# 9    13
# dtype: int32

# %%
s9.tail(7)
# Out:
# 3    62
# 4    56
# 5    43
# 6    61
# 7    43
# 8    82
# 9    13
# dtype: int32

# %%
s10 = pd.Series([1, 2, 3, np.nan, 4, 5])
s10
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
# count method
s10.count()
# Out:
# 5

# %%
s10.sum()
# Out:
# 15.0

# %%
s10.sum(skipna=False)
# Out:
# nan

# %%
# prodct(), cumsum(), pct_change(), mean(), median(), std(), min(), max()
# describe(), sample(), unique(), nunique()

# %%
# Date: June 26, 2026

# %%
s10
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
# parameter skipna=True by default, we can set it to False to include NaN
# in calculation
s10.sum(skipna=False)
# Out:
# nan

# %%
# min_count parameter is used to specify the minimum non-missing values
s10.sum(min_count=3) # at least 3 non-missing values
# Out:
# 15.0

# %%
s10.sum(min_count=4)
# Out:
# 15.0

# %%
s10.sum(min_count=5)
# Out:
# 15.0

# %%
s10.sum(min_count=6)
# Out:
# nan

# %%
# product() method with skipna and min_count parameters
s10.product()
# Out:
# 120.0

# %%
s10.product(skipna=False)
# Out:
# nan

# %%
s10.product(min_count=4)
# Out:
# 120.0

# %%
s10.product(min_count=6, skipna=True) # this doesn't make sense
# Out:
# nan

# %%
# cumsum() - cumulative sum
s10.cumsum()
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    15.0
# dtype: float64

# %%
s10.cumsum(skipna=False)
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %%
# pct_change() - percentage change
s10.pct_change() * 100
# Out:
# C:\Users\singa\AppData\Local\Temp\ipykernel_21728\3365929651.py:2: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   s10.pct_change() * 100
# 0           NaN
# 1    100.000000
# 2     50.000000
# 3      0.000000
# 4     33.333333
# 5     25.000000
# dtype: float64

# %%
s10
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
s10.pct_change(fill_method="pad") * 100
# Out:
# C:\Users\singa\AppData\Local\Temp\ipykernel_21728\169960454.py:1: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   s10.pct_change(fill_method="pad") * 100
# 0           NaN
# 1    100.000000
# 2     50.000000
# 3      0.000000
# 4     33.333333
# 5     25.000000
# dtype: float64

# %%
s10.pct_change(fill_method="ffill") * 100   # ffill or pad
# Out:
# C:\Users\singa\AppData\Local\Temp\ipykernel_21728\3487046877.py:1: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   s10.pct_change(fill_method="ffill") * 100
# 0           NaN
# 1    100.000000
# 2     50.000000
# 3      0.000000
# 4     33.333333
# 5     25.000000
# dtype: float64

# %%
s10.pct_change(fill_method="bfill") * 100 # bfill or backfill
# Out:
# C:\Users\singa\AppData\Local\Temp\ipykernel_21728\1949289169.py:1: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   s10.pct_change(fill_method="bfill") * 100 # bfill or backfill
# 0           NaN
# 1    100.000000
# 2     50.000000
# 3     33.333333
# 4      0.000000
# 5     25.000000
# dtype: float64

# %%
# mean()
s10.mean()
# Out:
# 3.0

# %%
# median()
s10.median()
# Out:
# 3.0

# %%
# standard deviation
s10.std()
# Out:
# 1.5811388300841898

# %%
# min()
s10.min()
# Out:
# 1.0

# %%
# max()
s10.max()
# Out:
# 5.0

# %%
# descriptive statistics - describe()
s10.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
# sample(n) - to select a random sample from the series
s10.sample(2)
# Out:
# 1    2.0
# 4    4.0
# dtype: float64

# %%
s10.sample(3)
# Out:
# 4    4.0
# 5    5.0
# 1    2.0
# dtype: float64

# %%
# unique() - find all the unique values
s10.unique()
# Out:
# array([ 1.,  2.,  3., nan,  4.,  5.])

# %%
# nunique() - count the number of unique values
s10.nunique()
# Out:
# 5

# %% [markdown]
# ### Arithmetic operations

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s1 + np.nan
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# dtype: float64

# %%
s1 + 5
# Out:
# 0    15
# 1    25
# 2    35
# 3    45
# dtype: int64

# %%
s1.add(10)
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# dtype: int64

# %%
s1 - 5
# Out:
# 0     5
# 1    15
# 2    25
# 3    35
# dtype: int64

# %%
s1.sub(5)  # s1.subtract(5)
# Out:
# 0     5
# 1    15
# 2    25
# 3    35
# dtype: int64

# %%
s1 * 3  # s1.mul(3)  or s1.multiply(3)
# Out:
# 0     30
# 1     60
# 2     90
# 3    120
# dtype: int64

# %%
s1 / 10 # s1.div(10) or s1.divide(10)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# dtype: float64

# %%
s1.floordiv(5)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
s1.mod(3)
# Out:
# 0    1
# 1    2
# 2    0
# 3    1
# dtype: int64

# %% [markdown]
# ### Broadcasting

# %%
s1 = pd.Series([10, 20, 30, 40])
s2 = pd.Series([1, 2, 3, 4])
s1 + s2
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64

# %%
s1 = pd.Series([10, 20, 30, 40])
s2 = pd.Series([1, 20, 3, 40])
s1 == s2  # s1.eq(s2)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s1 != s2  # s1.ne(s2)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# ### Popular functions with Series object

# %%
s10
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
len(s10)   # returns the number of elements in a series
# Out:
# 6

# %%
type(s10)
# Out:
# pandas.core.series.Series

# %%
dir(s10)   # lists all the methods and attributes of a sereis
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
list(s10)
# Out:
# [1.0, 2.0, 3.0, nan, 4.0, 5.0]

# %%
dict(s10)
# Out:
# {0: 1.0, 1: 2.0, 2: 3.0, 3: nan, 4: 4.0, 5: 5.0}

# %%
1 in s10
# Out:
# True

# %%
15 in s10
# Out:
# False

# %%
for i in s10.values:
    print(i, end=' ')
# Out:
# 1.0 2.0 3.0 nan 4.0 5.0
