# %% [markdown]
# # Introduction
# ## Introduction
# ### Introduction
# #### Introduction
# ##### Introduction
# ###### Introduction

# %% [markdown]
# Where there is a *will* there ***is*** a **way**.

# %% [markdown]
# - Python
# - Data analytics
# - Data Science
# - AI/ML
# - Agentic AI

# %% [markdown]
# - Communication skills
#     - Pubic speaking
#     - inter-personal communication
#     - intra-perswonal communication

# %% [markdown]
# [Click here](https://google.com)
